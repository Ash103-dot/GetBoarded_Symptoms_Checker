# %% [markdown]
# <a href="https://colab.research.google.com/github/newb-dev-1008/GetBoarded_Symptoms_Checker/blob/ipython/CoVID_Symptoms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Project to determine the probability of having contracted CoVID-19**
#
#   Objectives/ guidelines to keep in mind:
#
# *   Dropping irrelevant columns from the raw data
# *   Creating a covariance matrix with each symptom with all possible combinations (this is exactly what is in the Cleaned-Data.csv file)
# *   Creating a spider chart with all possible symptoms
# *   Using SVMs or Artificial Neural Nets to determine the probability of a user contracting CoVID-19 given his/her symptoms

# %%
import pandas as pd

#Creating dataframes for raw and cleaned data
raw_data = pd.read_csv('Raw-Data.csv')
cleaned_data = pd.read_csv('Cleaned-Data.csv')

#Note: Work on raw data and use the cleaned data only for reference purposes.

# %%
raw_data.head()
# Out:
#               Country    Age  ...  Severity    Contact
# 0               China    0-9  ...      Mild        Yes
# 1               Italy  10-19  ...  Moderate         No
# 2                Iran  20-24  ...    Severe  Dont-Know
# 3  Republic of Korean  25-59  ...      None        NaN
# 4              France    60+  ...       NaN        NaN
#
# [5 rows x 7 columns]

# %%
cleaned_data.head()
# Out:
#    Fever  Tiredness  Dry-Cough  ...  Contact_No  Contact_Yes  Country
# 0      1          1          1  ...           0            1    China
# 1      1          1          1  ...           1            0    China
# 2      1          1          1  ...           0            0    China
# 3      1          1          1  ...           0            1    China
# 4      1          1          1  ...           1            0    China
#
# [5 rows x 27 columns]
